# %%
# Hello there  :)*

# %%
import pandas as pd

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# My Goal is to  predict  servived  peaple so I go through base on it:
# 1. first  plot is  pairplot to  give  us a over view;

import seaborn as sns

sns.pairplot(df)

# %%
# 2. second  plot  is  count plot  of servived.

sns.countplot(x='Survived', data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# 3. How many women or men survived.

csns.barplot(x='Sex', y='Survived', data=df, hue='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
# 4. How many people survived in each  class.

sns.barplot(x='Pclass', y='Survived', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
# 5. How many people survived in each Embarked?

sns.barplot(x='Embarked', y='Survived', data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='Survived'>

# %%
# 6. does the ages  have any relation with Survived?

sns.stripplot(x='Survived', y='Age', data=df, jitter=True, hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
# 7. does the fare  have any relation with Survived?

sns.stripplot(x='Survived', y='Fare', data=df, jitter=True, hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>
